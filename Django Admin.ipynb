# %% [markdown]
# # Hacer Cambios en Modelos

# %%
from django.db import models

CHOICES_DIMENCIONES = ( 
    ("CH", "CHICO"),
    ("M", "MEDIANO"),
    ("G", "GRANDE")
)

CHOICES_COLORES = (
    ("AZ", "AZUL"),
    ("RO", "ROJO"),
    ("VE", "VERDE"),
    ("AM", "AMARILLO"),
    ("NE", "NEGRO"),
    ("BL", "BLANCO"),
    ("GR", "GRIS"),
    ("NA", "NARANJA"),
    ("ROSA", "ROSA"),
    ("MO", "MORADO"),
)

# Create your models here.
class ProductModel(models.Model):
    title = models.CharField(max_length=100)
    price = models.FloatField()
    descripcion = models.TextField(blank=True, null=True)
    vendedor = models.CharField(max_length=100,blank=True, null=True)
    color = models.CharField(max_length=4, choices=CHOICES_COLORES, default="NA")
    dimenciones = models.CharField(max_length=2, choices=CHOICES_DIMENCIONES, default= "CH")

# %% [markdown]
# pyrhon manage.py makemigrations
# python manage.py migrate
#
# <- esto se ejuta siempre para sicronizar base de datos ->

# %% [markdown]
# ## Como Borrar Un Campo

# %% [markdown]
# Se elimina el modelo que se desea eliminar Y se corren los comandos de makemigrations y migrate

# %% [markdown]
# ## Borrar Migraciones y Compresion de Migraciones

# %% [markdown]
# python manage.py squashmigrations <APP_LABEL> <MIGRATION_NUMBER>
#
# ## Ejemplo
#
# python manage.py squashmigrations ecommerce 004

# %% [markdown]
# ## Guardar Datos usando Shell

# %% [markdown]
# python manage.py shell

# %% [markdown]
# ProductModel.objects.create(title = "Desde shell", price = 1000)
# <ProductModel: ProductModel object (3)>

# %% [markdown]
# Queryset = lista de todos los modelos almacenados para cierto modelo
#
# queryset = NombredelModelo.objects.all()
#
# >>> qs = ProductModel.objects.all()
# >>> print (qs)
# <QuerySet [<ProductModel: ProductModel object (1)>, <ProductModel: ProductModel object (3)>]>
# >>> qs[0]
# <ProductModel: ProductModel object (1)>
# >>> qs[0].title
# 'Producto 1'
# >>> qs[1].title
# 'Desde shell'
# >>>
# >>> qs = ProductModel.objects.all()
# >>> print (qs.filter(title__icontains = "Shell"))
# <QuerySet [<ProductModel: ProductModel object (3)>]>
# >>
# >>>>> print (qs.get(id = 3))
# ProductModel object (3)
# >>
# >>ProductModel object (3)
# >>> my_product = qs.get(id = 3)
# >>> my_product.title
# 'Desde shell'
# >>> my_product.title = "Desde el Shell Modificado"
# >>> my_product.save()
# >>>
# >>> >>> ProductModel.objects.create(title = "Desde El Shell 2", price = 1000)
# <ProductModel: ProductModel object (4)>
# >>> qs
# <QuerySet [<ProductModel: ProductModel object (1)>, <ProductModel: ProductModel object (3)>, <ProductModel: ProductModel object (4)>]>
# >>> ProductModel.objects.get(id =
# ... 4).delete()
# (1, {'ecommerce.ProductModel': 1})
# >>> qs
# <QuerySet [<ProductModel: ProductModel object (1)>, <ProductModel: ProductModel object (3)>]>
# >>>

# %% [markdown]
# ## Validators
# from django.core.exceptions import ValidationError
#
#
#
# BLOQUED_WORDS = [
#     "Barato",
#     "Grátis",
#     "malo"
# ]
#
#
# def validate_blocked_words(value):
#     init_string = f'{value}'.lower()
#     unique_words = set(init_string.split())
#     blocked_words = set(BLOQUED_WORDS)
#     invalid_words = {unique_word & bloqued_word}
#     has_error = len(invalid_words) > 0
#     if has_error:
#         errors = []
#         for invalid_word in invalid_words:
#             msg = f'palabra "{invalid_word}" no permitida'
#             errors.append(msg)
#         raise ValidationError(errors)
#     return value

# %% [markdown]
# ## ecommerce/models.py
#
# from django.db import models
# from .validators import validate_blocked_words
#
# CHOICES_DIMENCIONES = (
#     ("CH", "CHICO"),
#     ("M", "MEDIANO"),
#     ("G", "GRANDE")
# )
#
# CHOICES_COLORES = (
#     ("AZ", "AZUL"),
#     ("RO", "ROJO"),
#     ("VE", "VERDE"),
#     ("AM", "AMARILLO"),
#     ("NE", "NEGRO"),
#     ("BL", "BLANCO"),
#     ("GR", "GRIS"),
#     ("NA", "NARANJA"),
#     ("ROSA", "ROSA"),
#     ("MO", "MORADO"),
# )
#
# # Create your models here.
# class ProductModel(models.Model):
#     title = models.CharField(max_length=100)
#     price = models.FloatField()
#     descripcion = models.TextField(blank=True, null=True)
#     vendedor = models.CharField(max_length=100,blank=True, null=True)
#     color = models.CharField(max_length=4, choices=CHOICES_COLORES, default="NA")
#     dimenciones = models.CharField(max_length=2, choices=CHOICES_DIMENCIONES, default= "CH")
#
#     def save(self, *args, **kwargs):
#         validate_blocked_words(self.title)
#         validate_blocked_words(self.descripcion)
#         super().save(*args, **kwargs)

# %% [markdown]
# >>> qs.create(title= "product barato", price = 1000)
# antes del if
# despues del if
# Traceback (most recent call last):
#   File "<console>", line 1, in <module>
#   File "/home/python/.local/lib/python3.14/site-packages/django/db/models/query.py", line 669, in create
#     obj.save(force_insert=True, using=self.db)
#     ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/src/ecommerce/models.py", line 33, in save
#     validate_blocked_words(self.title)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/app/src/ecommerce/validators.py", line 25, in validate_blocked_words
#     raise ValidationError(errors)
# django.core.exceptions.ValidationError: ['palabra "barato" no permitida']
# >>>

# %%
## Como agregar opciones a nuestros campos
ejemplo:
CHOICES_COLORES = (
    ("AZ", "AZUL"),
    ("RO", "ROJO"),
    ("VE", "VERDE"),
    ("AM", "AMARILLO"),
    ("NE", "NEGRO"),
    ("BL", "BLANCO"),
    ("GR", "GRIS"),
    ("NA", "NARANJA"),
    ("ROSA", "ROSA"),
    ("MO", "MORADO"),
)

la parte de la izquierda es como se guarda en nuestra base de datos
y la parte derecha es como se muestra al usuario

# %% [markdown]
# ## Agregar opciones con clases heredadas de django

# %% [markdown]
# class ProductModel(models.Model):
#     class ProductColorChoices(models.TextChoices):
#         AZUL = "AZ", "Azul"
#         ROJO = "RO", "Rojo"
#         VERDE = "VE", "Verde"
#         AMARILLO = "AM", "Amarillo"
#
#     title = models.CharField(max_length=100)
#     price = models.FloatField()
#     descripcion = models.TextField(blank=True, null=True)
#     vendedor = models.CharField(max_length=100,blank=True, null=True)
#     color = models.CharField(max_length=4, choices=ProductColorChoices.choices, default=ProductColorChoices.AZUL)
#     dimenciones = models.CharField(max_length=2, choices=CHOICES_DIMENCIONES, default= "CH")

# %% [markdown]
# ## Modelo Abstracto

# %% [markdown]
# ### base/models.py

# %% [markdown]
# from django.db import models
# from django.utils import timezone
#
#
#
# class BasePublishModel(models.Model):
#     class ProductStateChoices(models.TextChoices):
#         PUBLISHED = "PU", "Publicado"
#         DRAFT = "DR", "Borrador"
#         PRIVATE = "PR", "Privado"
#
#     state = models.CharField(max_length=2, choices=ProductStateChoices.choices, default=ProductStateChoices.DRAFT)
#     timestamp = models.DateTimeField(auto_now=True)
#     updated = models.DateTimeField(auto_now_add=True)
#     published_timestamp = models.DateTimeField(auto_now_add=False, auto_now=False, null=True)
#
#
#     class Meta:
#         abstract = True
#         ordering = ["-updated", "-timestamp"]
#
#     def save(self, *args, **kwargs):
#         if self.state_is_published and self.published_timestamp is None:
#             self.published_timestamp = timezone.now()
#         else:
#             self.published_timestamp = None
#         super().save(*args, **kwargs)
#
#     @property
#     def state_is_published(self):
#         return self.state == self.ProductStateChoices.PUBLISHED
#
#     def is_published(self):
#         publish_timestamp = self.published_timestamp
#         return self.state_is_published and publish_timestamp < timezone.now()

# %% [markdown]
# ## ecommerce/models.py

# %% [markdown]
# from django.db import models
# from .validators import validate_blocked_words
# from base.models import BasePublishModel
#
#
# class ProductModel(BasePublishModel):
#     title = models.CharField(max_length=100)
#     price = models.FloatField()
#     descripcion = models.TextField(blank=True, null=True)
#
#     def save(self, *args, **kwargs):
#         validate_blocked_words(self.title)
#         validate_blocked_words(self.descripcion)
#         super().save(*args, **kwargs)

# %% [markdown]
# ## Bulk_Create

# %% [markdown]
# data_generate_by_ia = [
# ...   { "title": "Laptop UltraBook 14", "price": 18500, "descripcion": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris." },
#
# >>> ProductModel.objects.bulk_create(new_objects, ignore_conflicts = True)

# %% [markdown]
# ## SlugField y Señales en Modelos

# %% [markdown]
# - slug: se usa para los URl's
# - title: algo como titulo
# - slug: algo-como-titulo
#
#   Signals
# - pre_save
# - post_save
# - pre_delete
# - post_delete
# - pre_migrate
# - post_migrate
# - pre_init
# - post_init

# %% [markdown]
# Python 3.14.5 (main, May 19 2026, 23:46:18) [GCC 14.2.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# (InteractiveConsole)
# >>> from ecommerce.models import ProductModel
# >>> obj1 = ProductModel.objects.create(title = "Testing Slug", price = 1000)
# antes del if
# antes del if
# >>> obj1.slug
# 'testing-slug'
# >>> obj1.slug = ""
# >>> obj1.slug
# ''
# >>> obj1.save()
# antes del if
# antes del if
# >>> obj1.slug
# 'testing-slug'
# >>> obj2 = ProductModel.objects.create(title = "Testing Slug", price = 1000)
# antes del if
# antes del if
# >>> obj2.slug
# 'testing-slug-1'
# >>>

# %% [markdown]
# ## Fixtures para cargar data

# %% [markdown]
# python manage.py dumpdata ecommerce --ident 4 --format json > ecommerce/fixtures/productdata.json
#
# python manage.py loaddata ecommerce/fixutres/productdata.json

# %% [markdown]
# ## Llaves Foraneas en Modelos

# %% [markdown]
# ecommerce/models.py
#
# from django.conf import settings <--------
# from django.db import models
# from .validators import validate_blocked_words
# from django.utils.text import slugify
# from django.db.models.signals import pre_save
# from base.models import BasePublishModel
#
# user = settings.AUTH_USER_MODEL <--------
# # Create your models here.
# class ProductModel(BasePublishModel):
#     title = models.CharField(max_length=100)
#     price = models.FloatField()
#     descripcion = models.TextField(blank=True, null=True)
#     slug = models.SlugField(unique=True, blank=True, null=True, db_index=True)
#     user = models.ForeignKey(user, on_delete=models.SET_NULL, null=True) <--------
#
#     def get_absolute_url(self):
#         return f'/product/{self.slug}/'
#
#     def save(self, *args, **kwargs):
#         validate_blocked_words(self.title)
#         validate_blocked_words(self.descripcion)
#         super().save(*args, **kwargs)
#
# def slugify_pre_save(sender, instance, *args, **kwargs):
#     if instance.slug is None or instance.slug == "":
#         new_slug = slugify(instance.title)
#         my_model = instance.__class__
#         qs = my_model.objects.filter(slug__startswith=new_slug).exclude(pk=instance.pk)
#         if qs.count() == 0:
#             instance.slug = new_slug
#         else:
#             instance.slug = f"{new_slug}-{qs.count()}"
#
# pre_save.connect(slugify_pre_save, sender=ProductModel)
